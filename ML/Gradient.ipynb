# %%
current_x = 2
rate = 0.01
precision = 0.000001
previous_step_size =1
max_iters = 1000
iters = 0
df = lambda x: 2*(x+3)
while previous_step_size > precision and iters < max_iters:
    previous_x = current_x
    current_x = current_x - rate * df(previous_x)
    previous_step_size = abs(current_x - previous_x)
    iters = iters + 1
    print("Iterations :",iters,"\nX values is ",current_x)
# Out:
# Iterations 1
# X values is  1.9
# Iterations 2
# X values is  1.8019999999999998
# Iterations 3
# X values is  1.70596
# Iterations 4
# X values is  1.6118408
# Iterations 5
# X values is  1.519603984
# Iterations 6
# X values is  1.42921190432
# Iterations 7
# X values is  1.3406276662336
# Iterations 8
# X values is  1.253815112908928
# Iterations 9
# X values is  1.1687388106507495
# Iterations 10
# X values is  1.0853640344377344
# Iterations 11
# X values is  1.0036567537489798
# Iterations 12
# X values is  0.9235836186740002
# Iterations 13
# X values is  0.8451119463005202
# Iterations 14
# X values is  0.7682097073745098
# Iterations 15
# X values is  0.6928455132270196
# Iterations 16
# X values is  0.6189886029624792
# Iterations 17
# X values is  0.5466088309032295
# Iterations 18
# X values is  0.4756766542851649
# Iterations 19
# X values is  0.40616312119946163
# Iterations 20
# X values is  0.3380398587754724
# Iterations 21
# X values is  0.27127906159996296
# Iterations 22
# X values is  0.2058534803679637
# Iterations 23
# X values is  0.14173641076060442
# Iterations 24
# X values is  0.07890168254539233
# Iterations 25
# X values is  0.017323648894484484
# Iterations 26
# X values is  -0.04302282408340521
# Iterations 27
# X values is  -0.10216236760173711
# Iterations 28
# X values is  -0.16011912024970237
# Iterations 29
# X values is  -0.21691673784470833
# Iterations 30
# X values is  -0.27257840308781417
# Iterations 31
# X values is  -0.3271268350260579
# Iterations 32
# X values is  -0.38058429832553675
# Iterations 33
# X values is  -0.432972612359026
# Iterations 34
# X values is  -0.4843131601118455
# Iterations 35
# X values is  -0.5346268969096086
# Iterations 36
# X values is  -0.5839343589714164
# Iterations 37
# X values is  -0.632255671791988
# Iterations 38
# X values is  -0.6796105583561483
# Iterations 39
# X values is  -0.7260183471890252
# Iterations 40
# X values is  -0.7714979802452447
# Iterations 41
# X values is  -0.8160680206403399
# Iterations 42
# X values is  -0.8597466602275331
# Iterations 43
# X values is  -0.9025517270229825
# Iterations 44
# X values is  -0.9445006924825228
# Iterations 45
# X values is  -0.9856106786328723
# Iterations 46
# X values is  -1.025898465060215
# Iterations 47
# X values is  -1.0653804957590107
# Iterations 48
# X values is  -1.1040728858438305
# Iterations 49
# X values is  -1.1419914281269539
# Iterations 50
# X values is  -1.1791515995644148
# Iterations 51
# X values is  -1.2155685675731265
# Iterations 52
# X values is  -1.2512571962216639
# Iterations 53
# X values is  -1.2862320522972306
# Iterations 54
# X values is  -1.320507411251286
# Iterations 55
# X values is  -1.3540972630262602
# Iterations 56
# X values is  -1.387015317765735
# Iterations 57
# X values is  -1.4192750114104202
# Iterations 58
# X values is  -1.4508895111822118
# Iterations 59
# X values is  -1.4818717209585675
# Iterations 60
# X values is  -1.512234286539396
# Iterations 61
# X values is  -1.5419896008086083
# Iterations 62
# X values is  -1.571149808792436
# Iterations 63
# X values is  -1.5997268126165873
# Iterations 64
# X values is  -1.6277322763642557
# Iterations 65
# X values is  -1.6551776308369706
# Iterations 66
# X values is  -1.6820740782202313
# Iterations 67
# X values is  -1.7084325966558267
# Iterations 68
# X values is  -1.7342639447227102
# Iterations 69
# X values is  -1.759578665828256
# Iterations 70
# X values is  -1.784387092511691
# Iterations 71
# X values is  -1.808699350661457
# Iterations 72
# X values is  -1.832525363648228
# Iterations 73
# X values is  -1.8558748563752634
# Iterations 74
# X values is  -1.8787573592477582
# Iterations 75
# X values is  -1.901182212062803
# Iterations 76
# X values is  -1.923158567821547
# Iterations 77
# X values is  -1.9446953964651161
# Iterations 78
# X values is  -1.9658014885358137
# Iterations 79
# X values is  -1.9864854587650975
# Iterations 80
# X values is  -2.0067557495897956
# Iterations 81
# X values is  -2.026620634598
# Iterations 82
# X values is  -2.04608822190604
# Iterations 83
# X values is  -2.065166457467919
# Iterations 84
# X values is  -2.0838631283185607
# Iterations 85
# X values is  -2.1021858657521895
# Iterations 86
# X values is  -2.1201421484371457
# Iterations 87
# X values is  -2.137739305468403
# Iterations 88
# X values is  -2.1549845193590347
# Iterations 89
# X values is  -2.171884828971854
# Iterations 90
# X values is  -2.188447132392417
# Iterations 91
# X values is  -2.204678189744569
# Iterations 92
# X values is  -2.2205846259496775
# Iterations 93
# X values is  -2.236172933430684
# Iterations 94
# X values is  -2.2514494747620706
# Iterations 95
# X values is  -2.266420485266829
# Iterations 96
# X values is  -2.2810920755614923
# Iterations 97
# X values is  -2.2954702340502626
# Iterations 98
# X values is  -2.3095608293692576
# Iterations 99
# X values is  -2.3233696127818724
# Iterations 100
# X values is  -2.336902220526235
# Iterations 101
# X values is  -2.3501641761157104
# Iterations 102
# X values is  -2.3631608925933962
# Iterations 103
# X values is  -2.375897674741528
# Iterations 104
# X values is  -2.3883797212466975
# Iterations 105
# X values is  -2.4006121268217635
# Iterations 106
# X values is  -2.4125998842853282
# Iterations 107
# X values is  -2.4243478865996217
# Iterations 108
# X values is  -2.4358609288676294
# Iterations 109
# X values is  -2.447143710290277
# Iterations 110
# X values is  -2.458200836084471
# Iterations 111
# X values is  -2.4690368193627816
# Iterations 112
# X values is  -2.479656082975526
# Iterations 113
# X values is  -2.4900629613160152
# Iterations 114
# X values is  -2.500261702089695
# Iterations 115
# X values is  -2.510256468047901
# Iterations 116
# X values is  -2.520051338686943
# Iterations 117
# X values is  -2.5296503119132043
# Iterations 118
# X values is  -2.53905730567494
# Iterations 119
# X values is  -2.5482761595614414
# Iterations 120
# X values is  -2.5573106363702127
# Iterations 121
# X values is  -2.5661644236428085
# Iterations 122
# X values is  -2.5748411351699523
# Iterations 123
# X values is  -2.5833443124665534
# Iterations 124
# X values is  -2.591677426217222
# Iterations 125
# X values is  -2.599843877692878
# Iterations 126
# X values is  -2.6078470001390204
# Iterations 127
# X values is  -2.61569006013624
# Iterations 128
# X values is  -2.623376258933515
# Iterations 129
# X values is  -2.6309087337548447
# Iterations 130
# X values is  -2.638290559079748
# Iterations 131
# X values is  -2.6455247478981527
# Iterations 132
# X values is  -2.6526142529401895
# Iterations 133
# X values is  -2.6595619678813858
# Iterations 134
# X values is  -2.666370728523758
# Iterations 135
# X values is  -2.6730433139532828
# Iterations 136
# X values is  -2.679582447674217
# Iterations 137
# X values is  -2.685990798720733
# Iterations 138
# X values is  -2.6922709827463183
# Iterations 139
# X values is  -2.698425563091392
# Iterations 140
# X values is  -2.7044570518295643
# Iterations 141
# X values is  -2.7103679107929732
# Iterations 142
# X values is  -2.7161605525771138
# Iterations 143
# X values is  -2.7218373415255717
# Iterations 144
# X values is  -2.72740059469506
# Iterations 145
# X values is  -2.7328525828011587
# Iterations 146
# X values is  -2.7381955311451356
# Iterations 147
# X values is  -2.743431620522233
# Iterations 148
# X values is  -2.748562988111788
# Iterations 149
# X values is  -2.7535917283495523
# Iterations 150
# X values is  -2.7585198937825615
# Iterations 151
# X values is  -2.76334949590691
# Iterations 152
# X values is  -2.768082505988772
# Iterations 153
# X values is  -2.7727208558689966
# Iterations 154
# X values is  -2.777266438751617
# Iterations 155
# X values is  -2.7817211099765844
# Iterations 156
# X values is  -2.7860866877770527
# Iterations 157
# X values is  -2.790364954021512
# Iterations 158
# X values is  -2.7945576549410815
# Iterations 159
# X values is  -2.79866650184226
# Iterations 160
# X values is  -2.802693171805415
# Iterations 161
# X values is  -2.8066393083693066
# Iterations 162
# X values is  -2.8105065222019205
# Iterations 163
# X values is  -2.8142963917578823
# Iterations 164
# X values is  -2.818010463922725
# Iterations 165
# X values is  -2.82165025464427
# Iterations 166
# X values is  -2.8252172495513848
# Iterations 167
# X values is  -2.828712904560357
# Iterations 168
# X values is  -2.83213864646915
# Iterations 169
# X values is  -2.8354958735397666
# Iterations 170
# X values is  -2.838785956068971
# Iterations 171
# X values is  -2.842010236947592
# Iterations 172
# X values is  -2.84517003220864
# Iterations 173
# X values is  -2.8482666315644676
# Iterations 174
# X values is  -2.851301298933178
# Iterations 175
# X values is  -2.8542752729545144
# Iterations 176
# X values is  -2.857189767495424
# Iterations 177
# X values is  -2.8600459721455156
# Iterations 178
# X values is  -2.8628450527026055
# Iterations 179
# X values is  -2.8655881516485535
# Iterations 180
# X values is  -2.8682763886155827
# Iterations 181
# X values is  -2.870910860843271
# Iterations 182
# X values is  -2.8734926436264057
# Iterations 183
# X values is  -2.8760227907538773
# Iterations 184
# X values is  -2.8785023349388
# Iterations 185
# X values is  -2.880932288240024
# Iterations 186
# X values is  -2.8833136424752235
# Iterations 187
# X values is  -2.885647369625719
# Iterations 188
# X values is  -2.8879344222332044
# Iterations 189
# X values is  -2.8901757337885403
# Iterations 190
# X values is  -2.8923722191127696
# Iterations 191
# X values is  -2.894524774730514
# Iterations 192
# X values is  -2.896634279235904
# Iterations 193
# X values is  -2.898701593651186
# Iterations 194
# X values is  -2.900727561778162
# Iterations 195
# X values is  -2.9027130105425987
# Iterations 196
# X values is  -2.9046587503317465
# Iterations 197
# X values is  -2.9065655753251116
# Iterations 198
# X values is  -2.9084342638186094
# Iterations 199
# X values is  -2.910265578542237
# Iterations 200
# X values is  -2.9120602669713924
# Iterations 201
# X values is  -2.9138190616319646
# Iterations 202
# X values is  -2.915542680399325
# Iterations 203
# X values is  -2.9172318267913386
# Iterations 204
# X values is  -2.918887190255512
# Iterations 205
# X values is  -2.920509446450402
# Iterations 206
# X values is  -2.9220992575213938
# Iterations 207
# X values is  -2.9236572723709657
# Iterations 208
# X values is  -2.9251841269235466
# Iterations 209
# X values is  -2.9266804443850756
# Iterations 210
# X values is  -2.928146835497374
# Iterations 211
# X values is  -2.9295838987874263
# Iterations 212
# X values is  -2.9309922208116777
# Iterations 213
# X values is  -2.932372376395444
# Iterations 214
# X values is  -2.933724928867535
# Iterations 215
# X values is  -2.9350504302901843
# Iterations 216
# X values is  -2.9363494216843806
# Iterations 217
# X values is  -2.937622433250693
# Iterations 218
# X values is  -2.938869984585679
# Iterations 219
# X values is  -2.9400925848939656
# Iterations 220
# X values is  -2.9412907331960865
# Iterations 221
# X values is  -2.9424649185321647
# Iterations 222
# X values is  -2.9436156201615216
# Iterations 223
# X values is  -2.944743307758291
# Iterations 224
# X values is  -2.9458484416031254
# Iterations 225
# X values is  -2.946931472771063
# Iterations 226
# X values is  -2.9479928433156415
# Iterations 227
# X values is  -2.9490329864493288
# Iterations 228
# X values is  -2.9500523267203422
# Iterations 229
# X values is  -2.9510512801859354
# Iterations 230
# X values is  -2.952030254582217
# Iterations 231
# X values is  -2.9529896494905725
# Iterations 232
# X values is  -2.953929856500761
# Iterations 233
# X values is  -2.954851259370746
# Iterations 234
# X values is  -2.955754234183331
# Iterations 235
# X values is  -2.9566391494996647
# Iterations 236
# X values is  -2.9575063665096715
# Iterations 237
# X values is  -2.958356239179478
# Iterations 238
# X values is  -2.9591891143958886
# Iterations 239
# X values is  -2.9600053321079707
# Iterations 240
# X values is  -2.960805225465811
# Iterations 241
# X values is  -2.9615891209564946
# Iterations 242
# X values is  -2.9623573385373647
# Iterations 243
# X values is  -2.9631101917666176
# Iterations 244
# X values is  -2.963847987931285
# Iterations 245
# X values is  -2.9645710281726596
# Iterations 246
# X values is  -2.9652796076092063
# Iterations 247
# X values is  -2.965974015457022
# Iterations 248
# X values is  -2.9666545351478817
# Iterations 249
# X values is  -2.967321444444924
# Iterations 250
# X values is  -2.9679750155560254
# Iterations 251
# X values is  -2.9686155152449047
# Iterations 252
# X values is  -2.969243204940007
# Iterations 253
# X values is  -2.9698583408412067
# Iterations 254
# X values is  -2.9704611740243827
# Iterations 255
# X values is  -2.9710519505438953
# Iterations 256
# X values is  -2.9716309115330173
# Iterations 257
# X values is  -2.9721982933023567
# Iterations 258
# X values is  -2.9727543274363097
# Iterations 259
# X values is  -2.9732992408875836
# Iterations 260
# X values is  -2.973833256069832
# Iterations 261
# X values is  -2.9743565909484353
# Iterations 262
# X values is  -2.9748694591294664
# Iterations 263
# X values is  -2.9753720699468773
# Iterations 264
# X values is  -2.9758646285479395
# Iterations 265
# X values is  -2.9763473359769805
# Iterations 266
# X values is  -2.976820389257441
# Iterations 267
# X values is  -2.9772839814722922
# Iterations 268
# X values is  -2.9777383018428463
# Iterations 269
# X values is  -2.9781835358059894
# Iterations 270
# X values is  -2.9786198650898696
# Iterations 271
# X values is  -2.9790474677880723
# Iterations 272
# X values is  -2.979466518432311
# Iterations 273
# X values is  -2.9798771880636648
# Iterations 274
# X values is  -2.9802796443023913
# Iterations 275
# X values is  -2.9806740514163437
# Iterations 276
# X values is  -2.9810605703880166
# Iterations 277
# X values is  -2.981439358980256
# Iterations 278
# X values is  -2.981810571800651
# Iterations 279
# X values is  -2.9821743603646382
# Iterations 280
# X values is  -2.9825308731573457
# Iterations 281
# X values is  -2.982880255694199
# Iterations 282
# X values is  -2.983222650580315
# Iterations 283
# X values is  -2.983558197568709
# Iterations 284
# X values is  -2.983887033617335
# Iterations 285
# X values is  -2.984209292944988
# Iterations 286
# X values is  -2.9845251070860885
# Iterations 287
# X values is  -2.984834604944367
# Iterations 288
# X values is  -2.9851379128454796
# Iterations 289
# X values is  -2.98543515458857
# Iterations 290
# X values is  -2.9857264514967983
# Iterations 291
# X values is  -2.9860119224668624
# Iterations 292
# X values is  -2.9862916840175253
# Iterations 293
# X values is  -2.9865658503371746
# Iterations 294
# X values is  -2.986834533330431
# Iterations 295
# X values is  -2.987097842663822
# Iterations 296
# X values is  -2.987355885810546
# Iterations 297
# X values is  -2.987608768094335
# Iterations 298
# X values is  -2.9878565927324483
# Iterations 299
# X values is  -2.9880994608777995
# Iterations 300
# X values is  -2.9883374716602438
# Iterations 301
# X values is  -2.988570722227039
# Iterations 302
# X values is  -2.988799307782498
# Iterations 303
# X values is  -2.989023321626848
# Iterations 304
# X values is  -2.989242855194311
# Iterations 305
# X values is  -2.989457998090425
# Iterations 306
# X values is  -2.9896688381286163
# Iterations 307
# X values is  -2.989875461366044
# Iterations 308
# X values is  -2.9900779521387233
# Iterations 309
# X values is  -2.990276393095949
# Iterations 310
# X values is  -2.99047086523403
# Iterations 311
# X values is  -2.9906614479293494
# Iterations 312
# X values is  -2.9908482189707626
# Iterations 313
# X values is  -2.9910312545913476
# Iterations 314
# X values is  -2.9912106294995207
# Iterations 315
# X values is  -2.9913864169095303
# Iterations 316
# X values is  -2.99155868857134
# Iterations 317
# X values is  -2.991727514799913
# Iterations 318
# X values is  -2.9918929645039145
# Iterations 319
# X values is  -2.9920551052138364
# Iterations 320
# X values is  -2.99221400310956
# Iterations 321
# X values is  -2.9923697230473687
# Iterations 322
# X values is  -2.9925223285864213
# Iterations 323
# X values is  -2.992671882014693
# Iterations 324
# X values is  -2.9928184443743993
# Iterations 325
# X values is  -2.9929620754869113
# Iterations 326
# X values is  -2.993102833977173
# Iterations 327
# X values is  -2.9932407772976295
# Iterations 328
# X values is  -2.993375961751677
# Iterations 329
# X values is  -2.993508442516643
# Iterations 330
# X values is  -2.9936382736663103
# Iterations 331
# X values is  -2.993765508192984
# Iterations 332
# X values is  -2.993890198029124
# Iterations 333
# X values is  -2.9940123940685415
# Iterations 334
# X values is  -2.994132146187171
# Iterations 335
# X values is  -2.9942495032634273
# Iterations 336
# X values is  -2.9943645131981587
# Iterations 337
# X values is  -2.9944772229341954
# Iterations 338
# X values is  -2.9945876784755114
# Iterations 339
# X values is  -2.9946959249060012
# Iterations 340
# X values is  -2.9948020064078813
# Iterations 341
# X values is  -2.9949059662797235
# Iterations 342
# X values is  -2.9950078469541292
# Iterations 343
# X values is  -2.995107690015047
# Iterations 344
# X values is  -2.995205536214746
# Iterations 345
# X values is  -2.995301425490451
# Iterations 346
# X values is  -2.995395396980642
# Iterations 347
# X values is  -2.9954874890410292
# Iterations 348
# X values is  -2.9955777392602085
# Iterations 349
# X values is  -2.9956661844750045
# Iterations 350
# X values is  -2.9957528607855046
# Iterations 351
# X values is  -2.9958378035697946
# Iterations 352
# X values is  -2.9959210474983986
# Iterations 353
# X values is  -2.9960026265484307
# Iterations 354
# X values is  -2.996082574017462
# Iterations 355
# X values is  -2.9961609225371126
# Iterations 356
# X values is  -2.9962377040863704
# Iterations 357
# X values is  -2.996312950004643
# Iterations 358
# X values is  -2.9963866910045502
# Iterations 359
# X values is  -2.9964589571844593
# Iterations 360
# X values is  -2.9965297780407703
# Iterations 361
# X values is  -2.996599182479955
# Iterations 362
# X values is  -2.9966671988303557
# Iterations 363
# X values is  -2.9967338548537485
# Iterations 364
# X values is  -2.9967991777566736
# Iterations 365
# X values is  -2.99686319420154
# Iterations 366
# X values is  -2.9969259303175093
# Iterations 367
# X values is  -2.9969874117111592
# Iterations 368
# X values is  -2.997047663476936
# Iterations 369
# X values is  -2.997106710207397
# Iterations 370
# X values is  -2.997164576003249
# Iterations 371
# X values is  -2.997221284483184
# Iterations 372
# X values is  -2.99727685879352
# Iterations 373
# X values is  -2.99733132161765
# Iterations 374
# X values is  -2.9973846951852967
# Iterations 375
# X values is  -2.997437001281591
# Iterations 376
# X values is  -2.9974882612559592
# Iterations 377
# X values is  -2.99753849603084
# Iterations 378
# X values is  -2.9975877261102233
# Iterations 379
# X values is  -2.9976359715880188
# Iterations 380
# X values is  -2.9976832521562584
# Iterations 381
# X values is  -2.9977295871131333
# Iterations 382
# X values is  -2.9977749953708708
# Iterations 383
# X values is  -2.997819495463453
# Iterations 384
# X values is  -2.9978631055541842
# Iterations 385
# X values is  -2.9979058434431005
# Iterations 386
# X values is  -2.9979477265742385
# Iterations 387
# X values is  -2.9979887720427536
# Iterations 388
# X values is  -2.9980289966018985
# Iterations 389
# X values is  -2.9980684166698603
# Iterations 390
# X values is  -2.9981070483364634
# Iterations 391
# X values is  -2.998144907369734
# Iterations 392
# X values is  -2.9981820092223392
# Iterations 393
# X values is  -2.9982183690378923
# Iterations 394
# X values is  -2.9982540016571346
# Iterations 395
# X values is  -2.998288921623992
# Iterations 396
# X values is  -2.998323143191512
# Iterations 397
# X values is  -2.998356680327682
# Iterations 398
# X values is  -2.9983895467211283
# Iterations 399
# X values is  -2.9984217557867057
# Iterations 400
# X values is  -2.9984533206709716
# Iterations 401
# X values is  -2.9984842542575523
# Iterations 402
# X values is  -2.9985145691724013
# Iterations 403
# X values is  -2.9985442777889535
# Iterations 404
# X values is  -2.9985733922331743
# Iterations 405
# X values is  -2.998601924388511
# Iterations 406
# X values is  -2.9986298859007405
# Iterations 407
# X values is  -2.998657288182726
# Iterations 408
# X values is  -2.998684142419071
# Iterations 409
# X values is  -2.9987104595706895
# Iterations 410
# X values is  -2.9987362503792756
# Iterations 411
# X values is  -2.99876152537169
# Iterations 412
# X values is  -2.9987862948642565
# Iterations 413
# X values is  -2.9988105689669715
# Iterations 414
# X values is  -2.998834357587632
# Iterations 415
# X values is  -2.9988576704358794
# Iterations 416
# X values is  -2.9988805170271617
# Iterations 417
# X values is  -2.9989029066866184
# Iterations 418
# X values is  -2.998924848552886
# Iterations 419
# X values is  -2.998946351581828
# Iterations 420
# X values is  -2.998967424550192
# Iterations 421
# X values is  -2.998988076059188
# Iterations 422
# X values is  -2.9990083145380044
# Iterations 423
# X values is  -2.9990281482472443
# Iterations 424
# X values is  -2.9990475852822995
# Iterations 425
# X values is  -2.9990666335766534
# Iterations 426
# X values is  -2.9990853009051204
# Iterations 427
# X values is  -2.999103594887018
# Iterations 428
# X values is  -2.999121522989278
# Iterations 429
# X values is  -2.999139092529492
# Iterations 430
# X values is  -2.9991563106789023
# Iterations 431
# X values is  -2.999173184465324
# Iterations 432
# X values is  -2.999189720776018
# Iterations 433
# X values is  -2.9992059263604975
# Iterations 434
# X values is  -2.9992218078332877
# Iterations 435
# X values is  -2.999237371676622
# Iterations 436
# X values is  -2.9992526242430895
# Iterations 437
# X values is  -2.9992675717582276
# Iterations 438
# X values is  -2.999282220323063
# Iterations 439
# X values is  -2.9992965759166017
# Iterations 440
# X values is  -2.9993106443982698
# Iterations 441
# X values is  -2.9993244315103045
# Iterations 442
# X values is  -2.9993379428800986
# Iterations 443
# X values is  -2.9993511840224967
# Iterations 444
# X values is  -2.9993641603420467
# Iterations 445
# X values is  -2.9993768771352056
# Iterations 446
# X values is  -2.9993893395925015
# Iterations 447
# X values is  -2.9994015528006517
# Iterations 448
# X values is  -2.9994135217446387
# Iterations 449
# X values is  -2.999425251309746
# Iterations 450
# X values is  -2.999436746283551
# Iterations 451
# X values is  -2.99944801135788
# Iterations 452
# X values is  -2.9994590511307226
# Iterations 453
# X values is  -2.999469870108108
# Iterations 454
# X values is  -2.999480472705946
# Iterations 455
# X values is  -2.999490863251827
# Iterations 456
# X values is  -2.999501045986791
# Iterations 457
# X values is  -2.999511025067055
# Iterations 458
# X values is  -2.999520804565714
# Iterations 459
# X values is  -2.9995303884744
# Iterations 460
# X values is  -2.999539780704912
# Iterations 461
# X values is  -2.9995489850908137
# Iterations 462
# X values is  -2.999558005388997
# Iterations 463
# X values is  -2.999566845281217
# Iterations 464
# X values is  -2.999575508375593
# Iterations 465
# X values is  -2.999583998208081
# Iterations 466
# X values is  -2.9995923182439195
# Iterations 467
# X values is  -2.999600471879041
# Iterations 468
# X values is  -2.9996084624414605
# Iterations 469
# X values is  -2.999616293192631
# Iterations 470
# X values is  -2.9996239673287786
# Iterations 471
# X values is  -2.999631487982203
# Iterations 472
# X values is  -2.999638858222559
# Iterations 473
# X values is  -2.9996460810581076
# Iterations 474
# X values is  -2.9996531594369453
# Iterations 475
# X values is  -2.9996600962482063
# Iterations 476
# X values is  -2.999666894323242
# Iterations 477
# X values is  -2.999673556436777
# Iterations 478
# X values is  -2.9996800853080416
# Iterations 479
# X values is  -2.999686483601881
# Iterations 480
# X values is  -2.999692753929843
# Iterations 481
# X values is  -2.9996988988512463
# Iterations 482
# X values is  -2.9997049208742212
# Iterations 483
# X values is  -2.999710822456737
# Iterations 484
# X values is  -2.999716606007602
# Iterations 485
# X values is  -2.9997222738874503
# Iterations 486
# X values is  -2.9997278284097013
# Iterations 487
# X values is  -2.9997332718415075
# Iterations 488
# X values is  -2.9997386064046774
# Iterations 489
# X values is  -2.999743834276584
# Iterations 490
# X values is  -2.999748957591052
# Iterations 491
# X values is  -2.999753978439231
# Iterations 492
# X values is  -2.9997588988704464
# Iterations 493
# X values is  -2.9997637208930374
# Iterations 494
# X values is  -2.999768446475177
# Iterations 495
# X values is  -2.9997730775456732
# Iterations 496
# X values is  -2.9997776159947596
# Iterations 497
# X values is  -2.999782063674864
# Iterations 498
# X values is  -2.999786422401367
# Iterations 499
# X values is  -2.9997906939533396
# Iterations 500
# X values is  -2.9997948800742726
# Iterations 501
# X values is  -2.9997989824727873
# Iterations 502
# X values is  -2.999803002823332
# Iterations 503
# X values is  -2.999806942766865
# Iterations 504
# X values is  -2.9998108039115277
# Iterations 505
# X values is  -2.999814587833297
# Iterations 506
# X values is  -2.999818296076631
# Iterations 507
# X values is  -2.9998219301550986
# Iterations 508
# X values is  -2.9998254915519964
# Iterations 509
# X values is  -2.9998289817209565
# Iterations 510
# X values is  -2.9998324020865375
# Iterations 511
# X values is  -2.9998357540448066
# Iterations 512
# X values is  -2.9998390389639105
# Iterations 513
# X values is  -2.9998422581846325
# Iterations 514
# X values is  -2.9998454130209398
# Iterations 515
# X values is  -2.999848504760521
# Iterations 516
# X values is  -2.9998515346653107
# Iterations 517
# X values is  -2.9998545039720046
# Iterations 518
# X values is  -2.9998574138925647
# Iterations 519
# X values is  -2.9998602656147133
# Iterations 520
# X values is  -2.999863060302419
# Iterations 521
# X values is  -2.9998657990963706
# Iterations 522
# X values is  -2.9998684831144433
# Iterations 523
# X values is  -2.9998711134521545
# Iterations 524
# X values is  -2.9998736911831116
# Iterations 525
# X values is  -2.9998762173594495
# Iterations 526
# X values is  -2.9998786930122607
# Iterations 527
# X values is  -2.9998811191520156
# Iterations 528
# X values is  -2.9998834967689754
# Iterations 529
# X values is  -2.9998858268335957
# Iterations 530
# X values is  -2.999888110296924
# Iterations 531
# X values is  -2.9998903480909855
# Iterations 532
# X values is  -2.999892541129166
# Iterations 533
# X values is  -2.9998946903065824
# Iterations 534
# X values is  -2.9998967965004506
# Iterations 535
# X values is  -2.9998988605704415
# Iterations 536
# X values is  -2.999900883359033
# Iterations 537
# X values is  -2.999902865691852
# Iterations 538
# X values is  -2.999904808378015
# Iterations 539
# X values is  -2.999906712210455
# Iterations 540
# X values is  -2.9999085779662455
# Iterations 541
# X values is  -2.9999104064069204
# Iterations 542
# X values is  -2.999912198278782
# Iterations 543
# X values is  -2.9999139543132065
# Iterations 544
# X values is  -2.9999156752269425
# Iterations 545
# X values is  -2.9999173617224035
# Iterations 546
# X values is  -2.9999190144879555
# Iterations 547
# X values is  -2.9999206341981965
# Iterations 548
# X values is  -2.9999222215142325
# Iterations 549
# X values is  -2.9999237770839478
# Iterations 550
# X values is  -2.9999253015422687
# Iterations 551
# X values is  -2.9999267955114233
# Iterations 552
# X values is  -2.999928259601195
# Iterations 553
# X values is  -2.999929694409171
# Iterations 554
# X values is  -2.9999311005209877
# Iterations 555
# X values is  -2.999932478510568
# Iterations 556
# X values is  -2.9999338289403563
# Iterations 557
# X values is  -2.9999351523615494
# Iterations 558
# X values is  -2.9999364493143186
# Iterations 559
# X values is  -2.9999377203280324
# Iterations 560
# X values is  -2.999938965921472
# Iterations 561
# X values is  -2.9999401866030424
# Iterations 562
# X values is  -2.9999413828709818
# Iterations 563
# X values is  -2.999942555213562
# Iterations 564
# X values is  -2.999943704109291
# Iterations 565
# X values is  -2.999944830027105
# Iterations 566
# X values is  -2.999945933426563
# Iterations 567
# X values is  -2.999947014758032
# Iterations 568
# X values is  -2.9999480744628713
# Iterations 569
# X values is  -2.999949112973614
# Iterations 570
# X values is  -2.999950130714142
# Iterations 571
# X values is  -2.999951128099859
